# %%
import numpy as np
import os
import random
import pandas as pd

# %%
def set_seed(seed=42):
    random.seed(seed)
    os.environ["PYTHONHASHSEED"] = str(seed)
    
    np.random.seed(seed)

    print(f"Seed {seed}")

set_seed(42)
# Out:
# Seed 42

# %%
def generate_synthetic_data(length):
    means = np.linspace(1, 10, length) # means from 1 to 10
    stddev = np.linspace(1, 10, length) # standard deviations from 1 to 10
    data = np.zeros(length)
    for t in range(length):
        data[t] = np.random.normal(loc=means[t], scale=stddev[t])

    return data

# %%
# Generate the synthetic values
length = 7588
values = generate_synthetic_data(length)

# Create daily dates instead of timestamps
dates = pd.date_range(start="1990-01-01", periods=length, freq="D").date

# Build the DataFrame
df = pd.DataFrame({
    "date": dates,
    "value": values
})

print(df.head())
# Out:
#          date     value
# 0  1990-01-01  1.496714
# 1  1990-01-02  0.862758
# 2  1990-01-03  1.651598
# 3  1990-01-04  2.532009
# 4  1990-01-05  0.769481

# %%
import matplotlib.pyplot as plt

plt.plot(df['date'], df['value'])
plt.title("Synthetic Time Series Data")
plt.xlabel("Date")
plt.ylabel("Value")
plt.xticks(rotation=90)
plt.show()

# %%
# Save to CSV
df.to_csv("data/linear_synthetic_data.csv", index=False)
